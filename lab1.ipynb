# %% [markdown]
# # 1.1

# %% [markdown]
# Nuskaityti simbolių eilutę. Jeigu pirmas ir paskutinis eilutės simboliai sutampa, išvesti "True", jeigu nesutampa – "False".
#
# Examples:
# standard input
# aaa bbb ccc dda
#
# standard output
# True
#
# standard input
# Aaa bbb ccc dda
#
# standard output
# False

# %%
string = input()
print(string[0] == string[-1])
# Out:
# aaa bbb aaa
# True

# %% [markdown]
# # 1.2

# %% [markdown]
# Duotas dviženklis sveikasis skaičius. Išveskite jį taip, kaip parodyta pavyzdyje:
#
# Example:
# standard input
# 23
#
# standard output
# 2*****3

# %%
number = input()
string = number[0] + "*" * 5 + number[-1]
print(string)
# Out:
# 12
# 1*****2

# %% [markdown]
# # 1.3

# %% [markdown]
# Parašykite programą, kuri leidžia nuskaityti darbuotojų duomenis iš klaviatūros. Pakeičia nuskaitytų reikšmių tipus į nurodytus skliaustuose ir rezultatą išveda ekrane.
# Nuskaito reikšmes
#
#     Employee No (int)Employee Name (str)
#     Employee Salary (float)
#     Employee Address (str)
#     Employee Married? [True|False] (bool)

# %%
no = int(input())
name = str(input())
salary = float(input())
address = str(input())
married = input()
if married == "False":
    married = bool(0)
else:
    married = bool(1)
print("Employee No:", no)
print("Employee Name:", name)
print("Employee Salary:", salary)
print("Employee Address:", address)
print("Employee Married?:", married)
# Out:
# 12
# Greg
# 12
# a
# 1
# Employee No: 12
# Employee Name: Greg
# Employee Salary: 12.0
# Employee Address: a
# Employee Married?: True

# %% [markdown]
# # 1.4

# %% [markdown]
# Importuokite modulį math.
# Parašykite programą, kuri nuskaito apskritimo spindulio reikšmę ir apskaičiuoja apskritimo plotą.
# π reikšmę reikia paimti iš modulio math
#
# Example
# standard input
#     1.5
#
# standard output
#     7.0685834705770345

# %%
import math
r = float(input())
S = math.pi * pow(r, 2)
print(S)
# Out:
# 12
# 452.3893421169302

# %% [markdown]
# # 1.5

# %% [markdown]
# Parašykite programą, kuri nuskaito simbolių eilutę ir išveda:
#
# tris pirmus simbolius
# tris paskutinius simbolius
# simbolius su lyginiais indeksais
# simbolius su nelyginiais indeksais
# eilutę atvirkštine tvarka
#
#
# Example
# standard input
# qwerty
#
#
# standard output
# qwe
# rty
# qet
# wry
# ytrewq

# %%
string = input()

print(string[0:3])
print(string[-3:])
print(string[0::2])
print(string[1::2])
print(string[::-1])
# Out:
# qwerty
# qwe
# rty
# qet
# wry
# ytrewq

# %% [markdown]
# # 1.6

# %% [markdown]
# Parašykite programą, kuri nuskaito triženklį skaičių ir išveda jo skaitmenų sumą. Nenaudokite dalybos.
#
# Example
# standard input
# 519
#
# standard output
# 15

# %%
s = input()

sum = int(s[0]) + int(s[1]) + int(s[2])

print(sum)
# Out:
# 123
# 6

# %% [markdown]
# # 1.7

# %% [markdown]
# Parašykite programą, kuri nuskaito sveiką skaičių ir išveda jį dvejetaine, aštuntaine ir šešioliktaine forma. Atsakymus išveskite stulpeliu. Komandą print galima naudoti tik vieną kartą
#
# Example
# standard input
# 2020
# standard output
# 0b11111100100
# 0o3744
# 0x7e4

# %%
inp = int(input())
print(f'{bin(inp)}\n{oct(inp)}\n{hex(inp)}')
# Out:
# 12
# 0b1100
# 0o14
# 0xc

# %% [markdown]
# # 1.8

# %% [markdown]
# Parašykite programą, kuri nuskaito stataus trikampio statinių a ir b ilgius ir išveda trikampio plotą.
# Reikšmes iš klaviatūros nuskaitykite viena eilute
#
# Example
# standard input
# 10.5 21
# standard output
# 110.25

# %%
x, y = input().split()

plot = (float(x) * float(y))/2

print(plot)
# Out:
# 1 2
# 1.0

# %% [markdown]
# # 1.9

# %% [markdown]
# Parašykite programą, kuri nuskaito minučių skaičių – n (n – sveikasis skaičius).
# Tiek minučių praėjo nuo paros pradžios.
# Nustatykite, kiek valandų ir minučių skaitmeninis laikrodis rodys šią akimirką.
# Išveskite valandų (nuo 0 iki 23) ir minučių (nuo 0 iki 59) skaičius.
# Skaičius n gali būti didesnis nei paros minučių skaičius
# Example
# standard input
# 3456
# standard output
# 9:36

# %%
inp = int(input())

para = 1440
diena = inp % para
h = int(diena / 60)
min = diena % 60
print(f'{round(h)}:{min}')
# Out:
# 10000000
# 10:40

# %% [markdown]
# # 1.10

# %% [markdown]
# Importuokite modulį math.
# Parašykite programą, kuri nuskaito x ir t reikšmes (x ir t – sveikieji skaičiai) ir išveda Z.
# Rezultatą pateikite su dviem skaitmenimis po kablelio.
#
# Z = \frac{9\pi t + 10cos(x)}{\sqrt{t}-|sin(t)|}*e^x
# Z=
# t
# ​
#  −∣sin(t)∣
# 9πt+10cos(x)
# ​
#  ∗e
# x
#
# Example
# standard input	standard output
# 10
# 1
#
# 2762685.71

# %%
import math
x = int(input())
t = int(input())
z = ((9 * math.pi * t + 10 * math.cos(x)) / (math.sqrt(t) - abs(math.sin(t)))) * pow(math.e, x)
print(round(z, 2))
# Out:
# 12
# 1
# 37691498.03
